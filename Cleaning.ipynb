# %%
import pandas as pd

# %%
data = pd.read_csv("../desktop/english_premier_league.csv", encoding="latin1")

# %%
data
# Out:
#                                                                                                                                                      english_premier_league (1)
# club_name       player_name      age position           club_involved_name fee                     transfer_movement fee_cleaned league_name    year                     season
# Manchester City Rodri            23  Defensive Midfield AtlÃ©tico Madrid   Â£63.00m                in                63          Premier League 2019                  2019/2020
#                 JoÃ£o Cancelo    25  Right-Back         Juventus           Â£58.50m                in                58.5        Premier League 2019                  2019/2020
#                 Pedro Porro      19  Right-Back         Girona             Â£10.80m                in                10.8        Premier League 2019                  2019/2020
# ...
